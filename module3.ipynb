# %% [markdown]
# B1]What is List?How will you reverse alist?
#
# ANS. A list is a data structure in python that is a mutable or changeble, ordered sequences of elements.Python lists can be reversed in-place with the list. reverse() method. This is a great option to reverse the order of a list in Python. It modifies the original container in-place which means no additional memory is required.

# %% [markdown]
# B2]How will you remove last object from a list?
#
# ANS.The simplest approach is to use the list's pop([i]) function, which removes an element present at the specified position in the list. If we don't specify any index, pop() removes and returns the last element in the list.

# %%
#B3]Suppose list1 is [2, 33, 222, 14, 25], What is list1[-1]?
list1=[2, 33, 222, 14, 25]
list1[-1]
# Out:
# 25

# %% [markdown]
# B4.Differentiate between append() and extend()methods.?
#
# ANS.The append() function can add a single element to the end of a list.
#     The extend () function can add a multiple element from the list supplied to it as argument

# %%
#B5. Write a Python function to get the largest number,smallest num and sum of all from alist
 
list=[]
n = int(input("how many number:"))
for i in range(n):
  numbers = int(input('Enter number '))
  list.append(numbers)

print("Maximum number is" ,max(list))
print("minimum number is" ,min(list))
# Out:
# how many number:2
# Enter number 3
# Enter number 5
# Maximum number is 5
# minimum number is 3

# %%
#B6)How will you compare two lists?
l1 = [1,2,3]
l2 = [1,2,3]
if l1 == l2:
 print("both lists are equal ")
else:
 print("both lists are not equal ")
# Out:
# both lists are equal

# %%
#B6)Write a Python program to count the number of strings where the string length is 2 or more and the first and last character are same from a given list of strings.

# %%
string=('abc', 'bcb')
s = 0
for i in string:
   if len(i)>=2 and i[0]==i[-1]:
    s+=1
    print(i)
   else:
    print("")
# Out:
# bcb

# %%
#7)Write a Python program to remove duplicates from a list.

l = [2,4,5,3,4,4,3,7]
a=[]
for i in l:
  if i not in a:
    a.append(i)
print(a)
# Out:
# [2, 4, 5, 3, 7]

# %%
#8)Write a Python program to check a list is empty or not.

l = [3]
if len(l)==0:
  print("list is empty")
else:
  print("list is not empty")
# Out:
# list is not empty

# %%
#9)Write a Python function that takes two lists and returns true if they have at least one common member.
def common_data(l1,l2):
 l1 = [2,3,4]
 l2 = [1,2,3]
 for x in l1:
  for y in l2:  
   if x == y:
    print("True")
  else:
    print("False")

# %%
#10)Write a Python program to generate and print a list of first and last 5 elements where the values are square of numbers between 1 and 30. 
l = []
for i in range(1,30):
  l.append(i**2)
print(l[:5])
print(l[-5:])
# Out:
# [1, 4, 9, 16, 25]
# [625, 676, 729, 784, 841]

# %%
#11)Write a Python function that takes a list and returns a new list with unique elements of the first list.

l = [2,4,5,3,4,4,3,7]
a=[]
for i in l:
  if i not in a:
    a.append(i)
print(a)
# Out:
# [2, 4, 5, 3, 7]

# %%
#12)Write a Python program to convert a list of characters into a string.

l = (['d','i','v','y','a'])
str=''.join(l)
print(str)
# Out:
# divya

# %%
#13)Write a Python program to select an item randomly from a list.
import random
color = ['black','red','blue','pink']
print(random.choice(color))
# Out:
# blue

# %%
#14)Write a Python program to find the second smallest number in a list.

l = [1,2,3,4,5]
l.sort()
print("second smallest number ",l[1])
# Out:
# second smallest number  2

# %%
#15)Write a Python program to get unique values from a list

l= [2,3,4,4,3,6,5,6,7,5,4]
a = []
for i in l:
  if i not in a:
    a.append(i)
print(a)
# Out:
# [2, 3, 4, 6, 5, 7]

# %%
#16)Write a Python program to check whether a list contains a sub list
l = []

# %%
#17)What is tuple? Difference between list and tuple.

# %% [markdown]
# 17 )what is tuple? Difference between list and tuple.
#
# ANS. Tuple are used to store multiple items in a single variable.Tuple is one of 4 built in data types in python used to store collections of data the other 3 are list,set and dictionary.
#
#                   DIFFERENCE BETWEEN LIST AND TUPLE :
# LIST:lists are mutable.
#      lists have several built in method.
#      Implication or iteration is time consuming.
# TYPLE:tuples are immutable.
#       Tuples does not have many several method.
#       Implication or iteration is faster.

# %%
#18)Write a Python program to create a tuple with different data types.

t = [3,7.8,'divya']
print(t)
# Out:
# [3, 7.8, 'divya']

# %%
#19)Write a Python program to create a tuple with numbers.

t = 4,5,2,7,4
print(t)
# Out:
# [4, 5, 2, 7, 4]

# %%
#20)Write a Python program to convert a tuple to a string.

t = ['k','a','r','t','i','k']
ts = ''.join(t)
print(ts)
# Out:
# kartik

# %%
#21)Write a Python program to check whether an element exists within a tuple.

t = [3,5,'d','y','a','k',8]
print('k' in t)
print(9 in t)
# Out:
# True
# False

# %%
#22)Write a Python program to find the length of a tuple.

t = ['divya',3,5]
print(len(t))
# Out:
# 3

# %%
#23)Write a Python program to convert a list to a tuple.

l = [2,3,8,9,7,6,5]
print(l)
# Out:
# [2, 3, 8, 9, 7, 6, 5]

# %%
#24)Write a Python program to reverse a tuple.

t = (1,2,3,4,5,6,7,8,9)
#rt = reversed(t)
#print(tuple(rt))

t[::-1]
# Out:
# (9, 8, 7, 6, 5, 4, 3, 2, 1)

# %%
#25)Write a Python program to replace last value of tuples in a list.

t = [(30,20,15), (15,25,40)]
for i in t:
  print([i[:-1] + (50,)])
# Out:
# [(30, 20, 50)]
# [(15, 25, 50)]

# %%
#26)Write a Python program to find the repeated items of a tuple.

t = [2,2,5,6,10,2,13,15,2,4,4,6]
count = t.count(4)
print(count)
# Out:
# 2

# %%
#27)Write a Python program to remove an empty tuple(s) from a list of tuples.

L = [3,5,6,(),(""),('a','b')]
L = [t for t in L if t]
print(L)
# Out:
# [3, 5, 6, ('a', 'b')]

# %%
#28)Write a Python program to unzip a list of tuples into individual lists.

l = [(2,4),(5,6),(7,8)]
print(list(zip(*l)))
# Out:
# [(2, 5, 7), (4, 6, 8)]

# %%
#29)Write a Python program to convert a list of tuples into a dictionary.

l = [('a',10),('b',12),('c',15)]
d = {}
for a,b in l:
  d.setdefault(a,[]).append(b)
print(d)
# Out:
# {'a': [10], 'b': [12], 'c': [15]}

# %%
#30)Write a Python script to sort (ascending and descending) a dictionary by value.
import operator
d = {1: 2, 3: 4, 4: 3, 2: 1, 0: 0}
sorted_d = sorted(d.items(), key=operator.itemgetter(1))
print('Dictionary in ascending order by value : ',sorted_d)
# Out:
# Dictionary in ascending order by value :  [(0, 0), (2, 1), (1, 2), (4, 3), (3, 4)]

# %%
#31)Write a Python script to concatenate following dictionaries to create a new one.

dic1={1:10, 2:20}
dic2={3:30, 4:40}
dic3={5:50,6:60}
dic4 = {}
for d in (dic1, dic2, dic3): dic4.update(d)
print(dic4)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
#32)Write a Python script to check if a given key already exists in a dictionary.

# %% [markdown]
# 33)How Do You Traverse Through A Dictionary Object In Python?
# There are two ways of iterating through a Python dictionary object. One is to fetch associated value for each key in keys() list. There is also items() method of dictionary object which returns list of tuples, each tuple having key and value.

# %% [markdown]
# 34)How Do You Check The Presence Of A Key In A Dictionary?
# has_key() method returns true if a given key is available in the dictionary, otherwise it returns a false.

# %%
#35)Write a Python script to print a dictionary where the keys are numbers between 1 and 15.
dic={}

for i in range(1,16):
    dic[i] = i**2

print(dic)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100, 11: 121, 12: 144, 13: 169, 14: 196, 15: 225}

# %%
#36)Write a Python program to check multiple keys exists in a dictionary

student = {
  'name': 'Divya',
  'class': 'V',
  'roll_id': '2'
}
print(student.keys() >= {'class', 'name'})
print(student.keys() >= {'name', 'Divya'})
print(student.keys() >= {'roll_id', 'name'})
# Out:
# True
# False
# True

# %%
#37)Write a Python script to merge two Python dictionaries

dict_1 = {1: 'a', 2: 'b'}
dict_2 = {2: 'c', 4: 'd'}

print(dict_1 | dict_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-4f0a89ec9a87> in <module>()
#       4 dict_2 = {2: 'c', 4: 'd'}
#       5
# ----> 6 print(dict_1 | dict_2)
#
# TypeError: unsupported operand type(s) for |: 'dict' and 'dict'

# %%
#38)Write a Python program to map two lists into a dictionary
keys = ['red', 'green', 'blue']
values = ['#FF0000','#008000', '#0000FF']
color_dictionary = dict(zip(keys, values))
print(color_dictionary)
# Out:
# {'red': '#FF0000', 'green': '#008000', 'blue': '#0000FF'}

# %%
#39)Write a Python program to combine two dictionary adding values for common keys.
# d1 = {'a': 100, 'b': 200, 'c':300}
# d2 = {'a': 300, 'b': 200,’d’:400}

d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d = {}
d.update(d1)
d.update(d2)
for i, j in d1.items():
  for x, y in d2.items():
    if i == x:
      d[i]=(j+y)
print(d)
# Out:
# {'a': 400, 'b': 400, 'c': 300, 'd': 400}

# %%
#40)Write a Python program to print all unique values in a dictionary.

dict = {'511':'Vishnu','512':'Vishnu','513':'Ram','514':'Ram','515':'sita'}
list =[] 
for val in dict.values(): 
  if val in list: 
    continue 
  else:
    list.append(val)

print (list)
# Out:
# ['Vishnu', 'Ram', 'sita']

# %% [markdown]
# 41)Why Do You Use the Zip () Method in Python?
#
# ANS)  Python's zip() function creates an iterator that will aggregate elements from two or more iterables. You can use the resulting iterator to quickly and consistently solve common programming problems, like creating dictionaries.

# %%
#42)Write a Python program to create and display all combinations of letters, selecting each letter from a different key in a dictionary.
# Sample data: {'1': ['a','b'], '2': ['c','d']}
# Expected Output:
# ac ad bc bd

d1 =  {'a','b'} 
d2 =  {'c','d'}
d = {}
d.update(d1) 
d.update(d2)
for i, j in d1.items():
  for x, y in d2.items():
    if i == x:
      d[i]=(j+y)
print(d)

# %%
#43)

my_dict = {'A': 67, 'B': 23, 'C': 45, 'D': 56, 'E': 12, 'F': 69}
print(my_dict, "\n")
print("Dictionary with 3 highest values:")
print("Keys: Values")
 
for i in my_dict:
    print(i[0]," :",i[1]," ")
# Out:
# {'A': 67, 'B': 23, 'C': 45, 'D': 56, 'E': 12, 'F': 69}
#
# Dictionary with 3 highest values:
# Keys: Values
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-16-631e8a33522d> in <module>()
#       7
#       8 for i in my_dict:
# ----> 9     print(i[0]," :",i[1]," ")
#
# IndexError: string index out of range

# %%
#44)Write a Python program to combine values in python list of dictionaries. Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300},
#{'item': 'item1', 'amount': 750}]
# Expected Output: Counter ({'item1': 1150, 'item2': 300})

# %%
#45)Write a Python function to calculate the factorial of a number (a non-negative integer)


def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)
n=int(input("Input a number to compute the factiorial : "))
print(factorial(n))
# Out:
# Input a number to compute the factiorial : 5
# 120

# %%
#46)Write a Python function to check whether a number is in a given range
def test_range(n):
    if n in range(3,9):
        print( " %s is in the range"%str(n))
    else :
        print("The number is outside the given range.")
test_range(5)
# Out:
#  5 is in the range

# %%
#47)Write a Python function to check whether a number is perfect or not.

def perfect_number(n):
    sum = 0
    for x in range(1, n):
        if n % x == 0:
            sum += x
    return sum == n
print(perfect_number(6))
# Out:
# True

# %%
#48)Write a Python function that checks whether a passed string is palindrome or not

# %% [markdown]
# 49)How do you perform pattern matching in Python? Explain

# %% [markdown]
# 50)What is lambda function in python? What we call a function which is incomplete version of a function?
#
# ANS)A Lambda Function in Python programming is an anonymous function or a function having no name. It is a small and restricted function having no more than one line. Just like a normal function, a Lambda function can have multiple arguments with one expression.

# %% [markdown]
# 51)How Many Basic Types Of Functions Are Available In Python?
#
# ANS)There are two types of functions: User-defined functions – These functions are defined by the user to perform a specific task. Built-in functions – These functions are pre-defined functions in Python.

# %% [markdown]
# 52)How can you pick a random item from a list or tuple?
#
# ANS)To get random elements from sequence objects such as lists, tuples, strings in Python, use choice() , sample() , choices() of the random module. choice() returns one random element, and sample() and choices() return a list of multiple random elements.0

# %% [markdown]
# 53)How can you pick a random item from a range?
#
# ANS)Use a random. randrange() function to get a random integer number from the given exclusive range by specifying the increment. For example, random. randrange(0, 10, 2) will return any random number between 0 and 20 (like 0, 2, 4, 6, 8)

# %%
#54)How can you get a random number in python?

import random

print(random.randint(0,9))
# Out:
# 8

# %% [markdown]
# 55)How will you set the starting value in generating random numbers?
#
# ANS)The random number generator needs a number to start with (a seed value), to be able to generate a random number. By default the random number generator uses the current system time. Use the seed() method to customize the start number of the random number generator.

# %% [markdown]
# 56)How will you randomizes the items of a list in place?
#
# ANS)The shuffle() method randomizes the items of a list in place.

# %%
#57)Write a Python program to read a random line from a file.

# %%
#58)Write a Python program to convert degree to radian

pi = 22/7
degrees = 5

radians = degrees * pi / 180
print(radians)
# Out:
# 0.0873015873015873

# %%
#59)Write a Python program to calculate the area of a trapezoid

height = float(input("Height of trapezoid: "))
base_1 = float(input('Base one value: '))
base_2 = float(input('Base two value: '))
area = ((base_1 + base_2) / 2) * height
print("Area is:", area)
# Out:
# Height of trapezoid: 5
# Base one value: 3
# Base two value: 6
# Area is: 22.5

# %%
#60)Write a Python program to calculate the area of a parallelogram

Base = float(input('Enter the Base of a parallelogram: '))
Height = float(input('Enter the Height of a parallelogram: '))
area=Base*Height  
print("The area of the parallelogram: ",area)
# Out:
# Enter the Base of a parallelogram: 50
# Enter the Height of a parallelogram: 5
# The area of the parallelogram= 250.0

# %%
#61)Write a Python program to calculate surface volume and area of a cylinder

pi=22/7
height = float(input('Height of cylinder: '))
radian = float(input('Radius of cylinder: '))
volume = pi * radian * radian * height

sur_area = ((2*pi*radian) * height) + ((pi*radian**2)*2)

print("Volume is: ", volume)
print("Surface Area is: ", sur_area)
# Out:
# Height of cylinder: 10
# Radius of cylinder: 10
# Volume is:  3142.8571428571427
# Surface Area is:  1257.142857142857

# %%
#62)Write a Python program to returns sum of all divisors of a number

num = int(input("enter any integer to find divisors = "))

print("The Divisors of the Number = ")

for i in range(1, num + 1):
    if num % i == 0:
        print(i)
# Out:
# Please enter any integer to find divisors = 50
# The Divisors of the Number =
# 1
# 2
# 5
# 10
# 25
# 50

# %%
#64)Write a Python program to find the maximum and minimum numbers from the specified decimal numbers.

data = list('2.45 2.69 2.45 3.45 2.00 0.04 7.25'.split())
print("Maximum: ", max(data))
print("Minimum: ", min(data))
# Out:
# Maximum:  7.25
# Minimum:  0.04
